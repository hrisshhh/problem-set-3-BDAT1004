# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\BDAT courses pdf\BDAT1004\roman-emperor-reigns.csv")

# %%
data = data[data["Cause_of_Death"]=="Assassinated"]

# %%
patches, texts = plt.pie(data.Length_of_Reign)
plt.legend(data.Emperor)
plt.show()
